# %% [markdown]
# <a href="https://colab.research.google.com/github/milesisang/fa5programactivity/blob/main/fa5programactivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function

def Item_purchase(a, b):
  return a * b

#main

num1=float(input("Enter the item price: "))
num2=int(input("Enter the item amount: "))

print("The total price is: ", Item_purchase(num1, num2))
# Out:
# Enter the item price: 17.50
# Enter the item amount: 5
# The total price is:  87.5
